# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(5,3), index=['a','c','e','f','h'], columns=['one', 'two', 'three'])

# %%
df = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])

# %%
df
# Out:
#         one       two     three
# a  0.322336  0.345386  0.720175
# b       NaN       NaN       NaN
# c  1.856502 -1.140111 -0.501422
# d       NaN       NaN       NaN
# e  0.032040 -1.420057 -0.738511
# f  0.453558 -0.955737 -0.890214
# g       NaN       NaN       NaN
# h -0.321624  0.897113 -0.793975

# %%
print(df['one'].median())
# Out:
# 0.32233595014016075

# %%
df.isnull().any()
# Out:
# one      True
# two      True
# three    True
# dtype: bool

# %%
print(df.isnull().sum())
# Out:
# one      3
# two      3
# three    3
# dtype: int64

# %%
print(df['one'].isnull().values.any())
# Out:
# True

# %%
print(df.isnull().sum().sum())
# Out:
# 9

# %%
print("NaN replaced with '0': ")
print(df.fillna(0))
# Out:
# NaN replaced with '0':
#         one       two     three
# a  0.322336  0.345386  0.720175
# b  0.000000  0.000000  0.000000
# c  1.856502 -1.140111 -0.501422
# d  0.000000  0.000000  0.000000
# e  0.032040 -1.420057 -0.738511
# f  0.453558 -0.955737 -0.890214
# g  0.000000  0.000000  0.000000
# h -0.321624  0.897113 -0.793975
